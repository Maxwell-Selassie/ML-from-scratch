# %%
import numpy as np
import mlflow

# %%
accuracy = np.arange(0, 1, 0.1)
loss = np.arange(1, 0, -0.1)
log_scale_loss = np.log1p(loss)
f1_score = np.arange(0, 1, 0.1)

batch_size = [2] * 5 + [4] * 5
learning_rate = [0.001, 0.01] * 5
models = ["GPT-2", "GPT-3","GPT-3.5","GPT-4"] + [None] * 6

task = ['classification','regression','casual lm'] + [None] * 7
environment = ['notebook'] * 5 + [None] * 5

dataset_name = ['custom'] * 5 + ['also_custom'] * 5
dataset_digest = ['sdg4e5gd','s4fg32fb'] + [None] * 8
dataset_context = ['train'] * 5 + ['test'] * 5

mlflow.set_experiment('search_run_guide')
for i in range(10):
    with mlflow.start_run():
        mlflow.log_metrics({
            'accuracy' : accuracy[i],
            'loss' : loss[i],
            'log_scale_loss' : log_scale_loss[i],
            'f1_score' : f1_score[i]
            }
        )
        mlflow.log_params({
            'batch_size' : batch_size[i],
            'learning_rate' : learning_rate[i],
            'models' : models[i]
        })

        mlflow.set_tags({
            'task' : task[i],
            'environment' : environment[i]
        })

        dataset = mlflow.data.from_numpy(
            features = np.random.uniform(size=[20, 28, 28, 3]),
            targets = np.random.randint(0, 10, size=[20]),
            name = dataset_name[i],
            digest = dataset_digest[i]
        )
        mlflow.log_input(dataset,context=dataset_context[i])

# %%
all_runs = mlflow.search_runs(
    filter_string="params.models ILIKE 'GPT%'",
    search_all_experiments=True)
print(all_runs)
# Out:
# WARNING:root:Malformed experiment '1'. Detailed error Yaml file 'C:\Users\Maxwe\OneDrive\Documents\ML-from-scratch\mlruns\1\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "c:\Users\Maxwe\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\store\tracking\file_store.py", line 376, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Maxwe\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\store\tracking\file_store.py", line 474, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Maxwe\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1644, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Maxwe\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1637, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Maxwe\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\utils\yaml_utils.py", line 104, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\Maxwe\OneDrive\Documents\ML-from-scratch\mlruns\1\meta.yaml' does not exist.
#                              run_id       experiment_id    status  \
# 0  984638962aad4dd6b9e348f660052d3a  466261452026652114  FINISHED
# 1  8636ef4e153a4b3ba1bc829a38a3bbe5  466261452026652114  FINISHED
# 2  3b506f50a8364ee89d1289cdc02e36b7  466261452026652114  FINISHED
# 3  223ac26f2a4f494cbc3d7aa134320931  466261452026652114  FINISHED
# 4  731c82ad226c494a9a9ddbe98607d8b3  466261452026652114  FINISHED
# 5  f2f9445a0c894058a1ead21dab0f8f5d  466261452026652114  FINISHED
# 6  38aa313e2a864babbd139f8535d9a5ff  466261452026652114  FINISHED
# 7  984a4ca4631b445aa1a1f7079a6f0277  466261452026652114  FINISHED
#
#                                         artifact_uri  \
# 0  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
# 1  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
# 2  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
# 3  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
# 4  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
# 5  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
# 6  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
# 7  file:///c:/Users/Maxwe/OneDrive/Documents/ML-f...
#
#                         start_time                         end_time  \
# 0 2026-01-07 08:45:30.122000+00:00 2026-01-07 08:45:30.422000+00:00
# 1 2026-01-07 08:45:29.741000+00:00 2026-01-07 08:45:30.096000+00:00
# 2 2026-01-07 08:45:29.291000+00:00 2026-01-07 08:45:29.713000+00:00
# 3 2026-01-07 08:45:28.938000+00:00 2026-01-07 08:45:29.259000+00:00
# 4 2026-01-07 08:43:35.750000+00:00 2026-01-07 08:43:35.936000+00:00
# 5 2026-01-07 08:43:35.503000+00:00 2026-01-07 08:43:35.722000+00:00
# 6 2026-01-07 08:43:35.220000+00:00 2026-01-07 08:43:35.490000+00:00
# 7 2026-01-07 08:43:34.610000+00:00 2026-01-07 08:43:35.178000+00:00
#
#    metrics.log_scale_loss  metrics.f1_score  metrics.loss  metrics.accuracy  \
# 0                0.530628               0.3           0.7               0.3
# 1                0.587787               0.2           0.8               0.2
# 2                0.641854               0.1           0.9               0.1
# 3                0.693147               0.0           1.0               0.0
# 4                0.530628               0.3           0.7               0.3
# 5                0.587787               0.2           0.8               0.2
# 6                0.641854               0.1           0.9               0.1
# 7                0.693147               0.0           1.0               0.0
#
#   params.learning_rate params.batch_size params.models   tags.mlflow.runName  \
# 0                 0.01                 2         GPT-4         clean-ray-780
# 1                0.001                 2       GPT-3.5         calm-shad-154
# 2                 0.01                 2         GPT-3    luxuriant-mole-326
# 3                0.001                 2         GPT-2           big-cow-826
# 4                 0.01                 2         GPT-4      bemused-kite-709
# 5                0.001                 2       GPT-3.5       brawny-shrew-88
# 6                 0.01                 2         GPT-3  enchanting-snipe-421
# 7                0.001                 2         GPT-2    carefree-quail-233
#
#                              tags.mlflow.source.name tags.mlflow.user  \
# 0  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
# 1  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
# 2  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
# 3  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
# 4  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
# 5  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
# 6  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
# 7  C:\Users\Maxwe\AppData\Roaming\Python\Python31...            Maxwe
#
#   tags.mlflow.source.type       tags.task tags.environment
# 0                   LOCAL            None         notebook
# 1                   LOCAL       casual lm         notebook
# 2                   LOCAL      regression         notebook
# 3                   LOCAL  classification         notebook
# 4                   LOCAL            None         notebook
# 5                   LOCAL       casual lm         notebook
# 6                   LOCAL      regression         notebook
# 7                   LOCAL  classification         notebook
